# %%
# %pip install boto3==1.34.0
# Out:
# Requirement already satisfied: boto3==1.34.0 in /opt/conda/lib/python3.11/site-packages (1.34.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.0 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.10.0,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (0.9.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.0->boto3==1.34.0) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.0->boto3==1.34.0) (2.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.0->boto3==1.34.0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
# Note importante : depuis le conteneur Jupyter, MinIO est accessible
# par son nom de service "minio", PAS par "localhost".
# C'est la résolution DNS automatique du réseau Compose.
s3 = boto3.client(
    "s3",
    endpoint_url="http://localhost:9000",
    aws_access_key_id="anfa-admin",
    aws_secret_access_key="anfa-password-2026",
)


# Vérifier la liste des
s3.list_buckets()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#       5 s3 = boto3.client(
#       6     "s3",
#       7     endpoint_url="http://localhost:9000",
#       8     aws_access_key_id="anfa-admin",
#       9     aws_secret_access_key="anfa-password-2026",
#      10 )
#      13 # Vérifier la liste des
# ---> 14 s3.list_buckets()
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:999, in BaseClient._make_api_call(self, operation_name, api_params)
#     995     maybe_compress_request(
#     996         self.meta.config, request_dict, operation_model
#     997     )
#     998     apply_request_checksum(request_dict)
# --> 999     http, parsed_response = self._make_request(
#    1000         operation_model, request_dict, request_context
#    1001     )
#    1003 self.meta.events.emit(
#    1004     f'after-call.{service_id}.{operation_name}',
#    1005     http_response=http,
#    (...)
#    1008     context=request_context,
#    1009 )
#    1011 if http.status_code >= 300:
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:1023, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1021 def _make_request(self, operation_model, request_dict, request_context):
#    1022     try:
# -> 1023         return self._endpoint.make_request(operation_model, request_dict)
#    1024     except Exception as e:
#    1025         self.meta.events.emit(
#    1026             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1027             exception=e,
#    1028             context=request_context,
#    1029         )
#
# File /opt/conda/lib/python3.11/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File /opt/conda/lib/python3.11/site-packages/botocore/endpoint.py:200, in Endpoint._send_request(self, request_dict, operation_model)
#     196 request = self.create_request(request_dict, operation_model)
#     197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
# --> 200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#     203     request_dict,
#     204     success_response,
#     205     exception,
#     206 ):
#     207     attempts += 1
#     208     self._update_retries_context(context, attempts, success_response)
#
# File /opt/conda/lib/python3.11/site-packages/botocore/endpoint.py:371, in Endpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     364 else:
#     365     # Request needs to be retried, and we need to sleep
#     366     # for the specified number of times.
#     367     logger.debug(
#     368         "Response received to retry, sleeping for %s seconds",
#     369         handler_response,
#     370     )
# --> 371     time.sleep(handler_response)
#     372     return True
#
# KeyboardInterrupt:

# %%
reponse = s3.list_objects_v2(Bucket="anfa-raw", Prefix="referentiel/")
for obj in reponse.get("Contents", []):
print(f"{obj['Key']} ({obj['Size']} octets)")
# Out:
#   Cell In[1], line 3
#     print(f"{obj['Key']} ({obj['Size']} octets)")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
import pandas as pd
from io import BytesIO
# Télécharger le CSV des lignes en mémoire
obj = s3.get_object(Bucket="anfa-raw", Key="referentiel/lignes.csv")
df_lignes = pd.read_csv(BytesIO(obj["Body"].read()))
df_lignes

# %%
# Top 3 des lignes les plus longues
df_lignes.nlargest(3, "distance_km")[["nom", "nb_arrets", "distance_km"]]
